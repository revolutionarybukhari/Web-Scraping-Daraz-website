# %% [markdown]
# # WEB SCRAPING DARAZ.PK BY Syed Husnain Haider Bukhari aka REVOLUTIONARY BUKHARI
# # copyright reserved

# %%
#import libraries
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, WebDriverException
from nltk.tokenize import word_tokenize

# %%
url="https://www.daraz.pk/products/pet-harness-for-cat-puppies-adjustable-color-choice-available-i113736966-s1393632717.html?spm=a2a0e.searchlistcategory.list.3.20814238XZ2IBD&search=1"

# %%
options = Options()
# options.add_argument("--headless")
#driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver  = webdriver.Chrome(ChromeDriverManager().install())
names = []
revw = []
count=1
driver.get(url)
#for page in driver.find_elements_by_class_name('next-pagination next-pagination-normal next-pagination-arrow-only next-pagination-medium medium review-pagination'):
for pn in range(0,2):
    if pn==1:
            time.sleep(5)
            aa=driver.find_elements_by_class_name("next-btn")[2]
            #button=aa.find_element_by_class_name("next-btn next-btn-normal next-btn-medium next-pagination-item")
            aa.click()
            time.sleep(5)
    for product in driver.find_elements_by_class_name('mod-reviews'):
        for n in product.find_elements_by_class_name('middle'):
            nm=n.find_element_by_tag_name('span').text
            names.append(nm)

        for tt in product.find_elements_by_class_name('item-content'):
            txt=tt.find_element_by_class_name('content').text
            revw.append(txt)
driver.close()
for i in range(len(names)):
    print(f'Name: {names[i]}, reviews: {revw[i]}')
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-7-414e5ab41be5>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver  = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-7-414e5ab41be5>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for product in driver.find_elements_by_class_name('mod-reviews'):
# C:\Users\HP\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:463: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# ...

# %%
# for i in range(len(names)):
#     print(f'Name: {names[i]}, reviews: {revw[i]}')
nl=[]
for i in names:
    name=i.split()
    nl.append(name[1])

df=pd.DataFrame(list(zip(nl, revw)),
               columns =['Name', 'reviews'])
df
# Out:
#       Name                                            reviews
# 0     Syed  The quality of the product was very good every...
# 1       Sh  the packing of cat harness is too good and fit...
# 2    Ovais  I love the colour..Good quality..Long enough.....
# 3       Sh  the cat harness is too good and it's fit on my...
# 4     Syed  jo mangwya tha wo nhi aya.. size ma bohat farq...
# 5   Omaima  Jesa pic mey show kiyaa tha wesi hi hai but no...
# 6    3***6  Very bad experience !\nI've ordered blue colou...
# 7  Tanveer  Excellent 🤗🌟🌟🌟🌟🌟\nMaterial is too good to be u...
# 8    Bilal  That is soo small .my cat is not want to were ...
# 9    3***7  sir you did not loose it yet..make sure you lo...

# %%
#Output
df
# Out:
#            Name                                            reviews
# 0          Syed  The quality of the product was very good every...
# 1            Sh  the packing of cat harness is too good and fit...
# 2         Ovais  I love the colour..Good quality..Long enough.....
# 3            Sh  the cat harness is too good and it's fit on my...
# 4        Omaima  Jesa pic mey show kiyaa tha wesi hi hai but no...
# 5       Tanveer  Excellent 🤗🌟🌟🌟🌟🌟\nMaterial is too good to be u...
# 6         Bilal  That is soo small .my cat is not want to were ...
# 7         3***7  sir you did not loose it yet..make sure you lo...
# 8  aroosanadeem  Same as shown... Satisfied with the services.....
# 9    *******917  i received my parcel wohh its so good in this ...

# %%
query = 'mobile covers'
url = f'https://www.daraz.pk/catalog/?from=input&q={query}'

# %%
options = Options()
# options.add_argument("--headless")
driver  = webdriver.Chrome(ChromeDriverManager().install())
query = input('Enter search term: ').replace(' ', '%20')
url = f'https://www.daraz.pk/catalog/?from=input&q={query}'
names = []
mall = []
country=[]
price = []
stars1 = []
revw = []
x=1
total_products=0
driver.get(url)
num=1
length=len(driver.find_elements_by_class_name('c3KeDq'))
lst=driver.find_elements_by_class_name('c3KeDq')
pos=1
for i in range(0,2):
    if num==80:    
            break
    if x== 40:
        print(x)
        print(num)
        x=0
        time.sleep(2)
        driver.find_element_by_xpath("//*[@id='root']/div/div[2]/div/div/div[1]/div[3]/div/ul/li[10]/a").click()
        time.sleep(2)
    for product in driver.find_elements_by_class_name('c3KeDq'):
        num+=1
        try:
            name = product.find_element_by_class_name('c16H9d').text
        except:
            try:
                name = product.find_element_by_class_name('c16H9d').text
            except:
                name=0
        
        try:
            prices=product.find_element_by_class_name('c3gUW0').text
        except:
            try:
                prices=product.find_element_by_class_name('c3gUW0').text
            except:
                prices=0
                
        #reviews=product.find_element_by_xpath(f'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[{x}]/div/div/div[2]/div[5]/div/span').text
        try:
            reviews=product.find_element_by_class_name('c3XbGJ').text
        except:
            try:
                reviews=product.find_element_by_class_name('c3XbGJ').text
            except:
                reviews=''
        try:
            mal=product.find_element_by_class_name('ic-dynamic-badge')
        except:
            time.sleep(2)
            try:
                mal=product.find_element_by_class_name('ic-dynamic-badge')
            except:
                mal=0
        if mal:
            mall.append(True)
        else:
            mall.append(False)
            
        try:
            sss=product.find_element_by_class_name('c2i43-').text
            country.append(sss)
        except:
            try:
                time.sleep(2)
                sss=product.find_element_by_class_name('c2i43-').text
                
            except:
                sss=''
        
        country.append(sss)    
        revw.append(reviews)
        price.append(prices)
        names.append(name)
        x+=1
        
        
#driver.back()
time.sleep(2)
driver.refresh()               
num_star=0
for p in range(0,3):
    if num_star==80:
        break
#     if p!=0:
#         try:
#             driver.find_element_by_xpath("//*[@id='root']/div/div[2]/div/div/div[1]/div[3]/div/ul/li[10]/a").click()
#             time.sleep(5)
#         except:
#             driver.refresh()
#             time.sleep(1)
#             driver.find_element_by_xpath("//*[@id='root']/div/div[2]/div/div/div[1]/div[3]/div/ul/li[10]/a").click()
#             time.sleep(2)
    
    for number in range(1,41):
        if num_star==80:
            break
        try:
            a= driver.find_element_by_xpath(f'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[{number}]/div/div/div[2]/div[2]/a').click()
            time.sleep(1)
        except:
            continue
            star=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[1]/div[2]/div/div/div[1]/div[1]/span[1]').text
            #stars1.append(star.text())
        stars1.append(float(star))
        driver.back()
        time.sleep(3)
        num_star+=1
    try:
        driver.refresh()
        time.sleep(2)
        clk=driver.find_element_by_xpath("//*[@id='root']/div/div[2]/div[1]/div/div[1]/div[3]/div/ul/li[3]").click()
    except:
        driver.refresh()
        time.sleep(2)
        clk=driver.find_element_by_xpath("//*[@id='root']/div/div[2]/div[1]/div/div[1]/div[3]/div/ul/li[3]").click()        
driver.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-23-94b16811f7e1>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver  = webdriver.Chrome(ChromeDriverManager().install())
# Enter search term: laptops
# <ipython-input-23-94b16811f7e1>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   length=len(driver.find_elements_by_class_name('c3KeDq'))
# <ipython-input-23-94b16811f7e1>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   lst=driver.find_elements_by_class_name('c3KeDq')
# ...

# %%
nrl=[]
np=[]
for p in price:
    b=word_tokenize(p)
    np.append(b[2])

for i in revw:
    a=i.replace('(',"")
    a=a.replace(')','')
    nrl.append(a)

df=pd.DataFrame(list(zip(names, np,nrl,stars1,mall,country)),
                 columns =['Name', 'price','reviews','stars','Daraz Mall','Country'])
df

# print(names)
# print(np)
# print(nrl)
# print(stars1)
# Out:
#                                                  Name    price reviews  stars  \
# 0   Infinix INBOOK X1 i3 - 14" - Intel Core i3 100...   78,999      75    4.8
# 1   Infinix INBOOK X1 i5 - 14" - Intel Core i5 10t...   98,999      51    4.8
# 2   Sony PlayStation 5 - Ps5 Console Disc Edition ...  184,999      16    4.8
# 3   HP Pro-Book 450G8 -  11th.Gen Intel® Core™ i5 ...  163,499      12    4.8
# 4   Lenovo Ideapad 330 - Intel Celeron N4000 - 15....   61,999      58    4.8
# ..                                                ...      ...     ...    ...
# 75  HP 15-DW3033dx Laptop 11th Gen Intel Core i3, ...   90,899       2    4.8
# 76  HP 255 G4 AMD A6 6th Gen 4GB Ram 500 GB Hard D...   31,500       5    4.8
# 77  Acer Nitro 5 15 GAMING - AMD RYZEN 7 4800H 16G...  185,999       1    4.8
# 78  Acer Travel Mate B117-MP-C2G3 11.6" HD Laptop ...   18,999       2    4.8
# 79  MacBook Pro 13-inch Space Gray M1 chip 512GB S...  305,000       1    4.8
#
#     Daraz Mall   Country
# ...

# %%
#Run this cell to see output
pd.read_csv('sample.csv')
# Out:
#                                                 Name  Actual Price  \
# 0  Blutooth Handfree Wireless Bluetooth Headset G...          1000
# 1  BUY 1 GET 1 FREE Wireless Bluetooth Hand Pod S...          1000
# 2                    Latest M5/M6 Smart Fitness Band          1999
# 3  Low Price Car Top Cover for Suzuki Cultus - Kh...           699
# 4  Pack of 2 Silicone Sink Drain Drainer Filter F...           250
#
#    Discounted Price  Discounted Percentage  Rating  Reviews  \
# 0               293                     71     4.1      361
# 1               564                     44     4.2      725
# 2              1099                     45     4.1      216
# 3               185                     74     4.5      349
# 4                99                     60     4.8      455
#
#                                             Review 1  \
# 0  mana blue order Kia tha our blue ka liya extra...
# 1  I ordered I7S double Wireless Bluetooth i find...
# ...

# %%
options = Options()
# options.add_argument("--headless")
driver  = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://www.daraz.pk'
name=[] 
price=[]
Discounted_price=[]
Discount_Percentage=[]
Rating=[]
No_of_Reviews=[] 
review1=[]
review2=[]
review3=[]
rev_top=[]
rev_2=[]
rev_3=[]
pos=1
total=0
x=1
driver.get(url)
try:
    time.sleep(2)
    clk=driver.find_element_by_class_name('card-fs-content-button').click()
    time.sleep(2)
except :
    driver.refresh()
    time.sleep(2)
    clk=driver.find_element_by_class_name('card-fs-content-button').click()
    time.sleep(2)  

length=len(driver.find_elements_by_class_name('unit-content'))
for product in driver.find_elements_by_class_name('unit-content'):
    
#     if x == (65):
#         break
    names = product.find_element_by_class_name('sale-title').text
    p=product.find_element_by_class_name('sale-price')
    D_price=p.text
    if D_price!="Rs ? ? ?":
        total+=1
    else:
        break
    prices=product.find_element_by_class_name('origin-price-value').text
    try:
        dd=product.find_element_by_class_name('discount').text
    except:
        dd=0 #if no discount then it is zero
    name.append(names)
    price.append(prices)
    Discounted_price.append(D_price)
    Discount_Percentage.append(dd)
    time.sleep(2)
    x+=1
for number in range(1,total):
        try:
            try:
                a= driver.find_element_by_xpath(f'//*[@id="campaign-1637348400000"]/div/a[{number}]/div/div[2]/div[1]').click()
                time.sleep(5)
            except:
                driver.refresh()
                time.sleep(5)
                a= driver.find_element_by_xpath(f'//*[@id="campaign-1637348400000"]/div/a[{number}]/div/div[2]/div[1]').click()

        except:
            try:
                driver.refresh()
                time.sleep(5)
                a= driver.find_element_by_xpath(f'//*[@id="campaign-1637348400000"]/div/a[{number}]/div/div[2]/div[1]').click()
            except:
                continue
        try:
            star=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[1]/div[2]/div/div/div[1]/div[1]/span[1]').text
        except:
            driver.refresh()
            time.sleep(5)
            star=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[1]/div[2]/div/div/div[1]/div[1]/span[1]').text
        try:
            reviews=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[1]/div[2]/div/div/div[1]/div[1]/span[1]').text
            no_rev=driver.find_element_by_xpath('//*[@id="module_product_review_star_1"]/div/a').text
        except:
            driver.refresh()
            time.sleep(5)
            reviews=driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[1]/div[2]/div/div/div[1]/div[1]/span[1]').text
            no_rev=driver.find_element_by_xpath('//*[@id="module_product_review_star_1"]/div/a').text
        try:
            review_top=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{1}]/div[3]/div[1]').text
        except:
            driver.refresh()
            time.sleep(5)
            review_top=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{1}]/div[3]/div[1]').text

        try:
            time.sleep(5) 
            rev_2=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{2}]/div[3]/div[1]').text
        except:
            driver.refresh()
            time.sleep(5)
            rev_2=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{2}]/div[3]/div[1]').text
        try:
            time.sleep(5) 
            rev_3=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{3}]/div[3]/div[1]').text
        except:
            driver.refresh()
            time.sleep(5)
            rev_3=driver.find_element_by_xpath(f'//*[@id="module_product_review"]/div/div[3]/div[1]/div[{3}]/div[3]/div[1]').text
        
        review3.append(rev_3)
        Rating.append(float(star))
        No_of_Reviews.append(no_rev)
        review1.append(review_top)
        review2.append(rev_2)
        
        time.sleep(5)  
        driver.back()
        time.sleep(5)
        
driver.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-20-a767160bea8d>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver  = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-20-a767160bea8d>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   clk=driver.find_element_by_class_name('card-fs-content-button').click()
# <ipython-input-20-a767160bea8d>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   length=len(driver.find_elements_by_class_name('unit-content'))
# ...

# %%
dsp=[]
np=[]
disc_pc=[]
revws=[]
for rev in No_of_Reviews:
    a=rev.split()
    revws.append(a[0])
for p in price:
    b=p.split(".")
    np.append(b[1])
for dp in Discounted_price:
    b=dp.split(".")
    dsp.append(b[1])

for j in Discount_Percentage:
    a=str(j)
    b=word_tokenize(a)
    wrd=str(b[0])
    disc_pc.append(wrd[1:])
df=pd.DataFrame(list(zip(name, np,dsp,disc_pc,Rating,revws,review1,review2,review3)),
                columns =['Name', 'price','discounted price','discount percentage','Rating','reviews','review1','review2','review3'])
df
# Out:
#                                                  Name  price discounted price  \
# 0         i12_air buds / Earphones With Charging Case  1,999              630
# 1   I7S AND i12 Double Wireless Bluetooth Hand Fre...  1,999              526
# 2   Pack of 4 mini Foundation Sponge Blender Beaut...    200              135
# 3   IELGY Pleated waist slimming French retro slee...  4,424            1,576
# 4   FRAKIN 15 Holes Scarf Hanger Multi Scarves Dis...    350              235
# 5   100 Dots Removable Adhesive Glue Dot Foil Ball...     49               33
# 6   Name/Logo Customized 3D Fasion Masks Unisex Re...    199              170
# 7   Ghilaf-e-Kaaba Attar Concentrated Perfume Oil ...    225              124
# 8   Artisan - Acrylic Paint Set Of 24 Pieces 12ML ...    949              901
# 9   SKMEI New Fashion Quartz Dual Display Waterpro...  4,999            2,339
# 10  Happy Birthday Banner with (30) High quality B...    299              246
# ...
